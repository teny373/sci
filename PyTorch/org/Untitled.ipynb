# %%
# -*- coding: utf-8 -*-
"""
Created on Mon Feb 20 13:38:16 2023

@author: Lenovo
"""

import time
from torch.utils.tensorboard import SummaryWriter
from torchvision.datasets import ImageFolder
from torchvision import transforms #导入图像预处理模块
from torch.utils.data import DataLoader #匹量读取数据并打乱数据
import torchvision.models as models
import torch.nn as nn #导入神经模块
import torch #导入pytorch主库

#接着检查是否可以使用 GPU 加速，并打印 GPU 名称。
print("是否使用GPU训练：{}".format(torch.cuda.is_available()))    #打印是否采用gpu训练
if torch.cuda.is_available:
    print("GPU名称为：{}".format(torch.cuda.get_device_name()))  #打印相应的gpu信息
#所有图像统一缩放到 640×640。
# 归一化操作将像素值压缩到 [-1, 1]，有助于模型收敛。
# 将 PIL 图像转换为 PyTorch Tensor。
normalize=transforms.Normalize(mean=[.5,.5,.5], std=[.5,.5,.5]) #规范化
transform=transforms.Compose([transforms.Resize((640, 640)),transforms.ToTensor(),normalize]) #数据处理，转为张量
dataset_train=ImageFolder('add_label/label_picture/train',transform=transform)     #训练数据集
# print(dataset_tran[0])
dataset_test=ImageFolder('add_label/label_picture/test',transform=transform)     #验证或测试数据集


# print(dataset_train.classer)#返回类别
print(dataset_train.class_to_idx)                               #返回类别及其索引
# print(dataset_train.imgs)#返回图片路径
print(dataset_test.class_to_idx)

train_data_size=len(dataset_train)                              #放回数据集长度
test_data_size=len(dataset_test)

print("训练数据集的长度为：{}".format(train_data_size))
print("测试数据集的长度为：{}".format(test_data_size))

#每批加载16张图像，打乱顺序。
#设置 drop_last=True，确保每个 batch 大小一致。
dataloader_train=DataLoader(dataset_train,batch_size=16,shuffle=True,num_workers=0,drop_last=True)
dataloader_test=DataLoader(dataset_test,batch_size=16,shuffle=True,num_workers=0,drop_last=True)

#模型加载
model_ft=models.resnet50(pretrained=True)#使用迁移学习，加载预训练权重
# print(model_ft)

in_features=model_ft.fc.in_features
model_ft.fc=nn.Sequential(nn.Linear(in_features,36),nn.Linear(36,4))#将最后的全连接改为（36，6），使输出为六个小数，对应四个树种的置信度


model_ft=model_ft.cuda()#将模型迁移到gpu

#pytorch2.0编译模型部分
# model_ft=torch.compile(model_ft)

#使用交叉熵损失函数，适合分类任务。
#使用带动量的 SGD 进行权重更新。
loss_fn=nn.CrossEntropyLoss()

loss_fn=loss_fn.cuda()  #将loss迁移到gpu
learn_rate=0.0001       #设置学习率
optimizer=torch.optim.SGD(model_ft.parameters(),lr=learn_rate,momentum=0.001)#可调超参数


total_train_step=0
total_test_step=0


epoch=100              #迭代次数
writer=SummaryWriter("logs")
best_acc=-1
ss_time=time.time()

#迭代所有训练数据：前向传播 → 反向传播 → 权重更新。
for i in range(epoch):
    start_time = time.time()
    print("--------第{}轮训练开始---------".format(i+1))
    model_ft.train()
    for data in dataloader_train:
        imgs,targets=data
        imgs=imgs.cuda()
        targets=targets.cuda()
        outputs=model_ft(imgs)
        loss=loss_fn(outputs,targets)

        optimizer.zero_grad()   #梯度归零
        loss.backward()         #反向传播计算梯度
        optimizer.step()        #梯度优化

        total_train_step=total_train_step+1
        if total_train_step%100==0:#一轮时间过长可以考虑加一个
            end_time=time.time()
            print("使用GPU训练100次的时间为：{}".format(end_time-start_time))
            print("训练次数：{},loss:{}".format(total_train_step,loss.item()))

    model_ft.eval()
    
    total_test_loss=0
    total_test_accuracy=0
    
    total_train_loss=0
    total_train_accuracy=0


    with torch.no_grad():       #验证数据集时禁止反向传播优化权重
      #记录训练集精度和损失值
        for data in dataloader_train:
            imgs,targets=data
            imgs = imgs.cuda()
            targets = targets.cuda()
            outputs=model_ft(imgs)
            train_loss=loss_fn(outputs,targets)
            total_train_loss=total_train_loss+train_loss.item()
            train_accuracy=(outputs.argmax(1)==targets).sum()
            total_train_accuracy=total_train_accuracy+train_accuracy
        print("整体训练集上的loss：{}(越小越好,与上面的loss无关此为测试集的总loss)".format(total_train_loss))
        print("整体训练集上的正确率：{}(越大越好)".format(total_train_accuracy / len(dataset_train)))
       
        for data in dataloader_test:
            imgs,targets=data
            imgs = imgs.cuda()
            targets = targets.cuda()
            outputs=model_ft(imgs)
            test_loss=loss_fn(outputs,targets)
            total_test_loss=total_test_loss+test_loss.item()
            test_accuracy=(outputs.argmax(1)==targets).sum()
            total_test_accuracy=total_test_accuracy+test_accuracy
        print("整体测试集上的loss：{}(越小越好,与上面的loss无关此为测试集的总loss)".format(total_test_loss))
        print("整体测试集上的正确率：{}(越大越好)".format(total_test_accuracy / len(dataset_test)))


        # 记录到 TensorBoard
        writer.add_scalar("Train Accuracy", total_train_accuracy / len(dataset_train), i)
        writer.add_scalar("Train Loss", total_train_loss, i)
        writer.add_scalar("Test Accuracy", total_test_accuracy/len(dataset_test), i)
        writer.add_scalar("Test Loss", total_test_loss, i)


        total_test_step = total_test_step + 1
      #若当前验证集准确率超过历史最好，保存模型权重。
      #确保最终部署的是性能最好的模型。
        if total_test_accuracy > best_acc:   #保存迭代次数中最好的模型
            print("已修改模型")
            best_acc = total_test_accuracy
            torch.save(model_ft.state_dict(), "best_model.pth")      #只保留权重的参数即可 
# # 绘制训练和测试精度和损失曲线
# plt.figure(figsize=(12, 4))
# plt.subplot(1, 2, 1)
# plt.plot(total_train_loss, label='Train Loss')
# plt.plot(total_test_loss, label='Test Loss')
# plt.xlabel('Epoch')
# plt.ylabel('Loss')
# plt.legend()


# plt.subplot(1, 2, 2)
# plt.plot(total_train_accuracy / len(dataset_train), label='Train Accuracy')
# plt.plot(total_test_accuracy/len(dataset_test), label='Test Accuracy')
# plt.xlabel('Epoch')
# plt.ylabel('Accuracy (%)')
# plt.legend()
# plt.show()
ee_time=time.time()
zong_time=ee_time-ss_time
print("训练总共用时:{}h:{}m:{}s".format(int(zong_time//3600),int((zong_time%3600)//60),int(zong_time%60))) #打印训练总耗时
writer.close()
# Out:
# 是否使用GPU训练：True
# GPU名称为：NVIDIA GeForce RTX 3060
# {'fir': 0, 'pine': 1, 'spruce': 2, 'trembling aspen': 3}
# {'fir': 0, 'pine': 1, 'spruce': 2, 'trembling aspen': 3}
# 训练数据集的长度为：597
# 测试数据集的长度为：85
# /venv/main/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /venv/main/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:01<00:00, 98.3MB/s]
# --------第1轮训练开始---------
# 整体训练集上的loss：51.310484409332275(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.3584589660167694(越大越好)
# 整体测试集上的loss：6.979351162910461(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.3294117748737335(越大越好)
# 已修改模型
# --------第2轮训练开始---------
# 整体训练集上的loss：50.43992304801941(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.3819095492362976(越大越好)
# 整体测试集上的loss：6.860100865364075(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.30588236451148987(越大越好)
# --------第3轮训练开始---------
# 使用GPU训练100次的时间为：15.836288452148438
# 训练次数：100,loss:1.369537591934204
# 整体训练集上的loss：49.701184153556824(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.36180904507637024(越大越好)
# 整体测试集上的loss：6.773598313331604(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.30588236451148987(越大越好)
# --------第4轮训练开始---------
# 整体训练集上的loss：49.06784009933472(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.3668341636657715(越大越好)
# 整体测试集上的loss：6.7054349184036255(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.38823530077934265(越大越好)
# 已修改模型
# --------第5轮训练开始---------
# 整体训练集上的loss：48.65291368961334(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.39698493480682373(越大越好)
# 整体测试集上的loss：6.702193737030029(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.364705890417099(越大越好)
# --------第6轮训练开始---------
# 使用GPU训练100次的时间为：8.907164812088013
# 训练次数：200,loss:1.2925165891647339
# 整体训练集上的loss：48.189781188964844(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.4254606366157532(越大越好)
# 整体测试集上的loss：6.589076995849609(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.4000000059604645(越大越好)
# 已修改模型
# --------第7轮训练开始---------
# 整体训练集上的loss：47.85004484653473(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.4371859133243561(越大越好)
# 整体测试集上的loss：6.567286014556885(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.4000000059604645(越大越好)
# --------第8轮训练开始---------
# 整体训练集上的loss：47.50820696353912(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.4505862593650818(越大越好)
# 整体测试集上的loss：6.606810569763184(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.3764705955982208(越大越好)
# --------第9轮训练开始---------
# 使用GPU训练100次的时间为：2.001282215118408
# 训练次数：300,loss:1.3636229038238525
# 整体训练集上的loss：47.267765402793884(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.4606364965438843(越大越好)
# 整体测试集上的loss：6.511350035667419(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.38823530077934265(越大越好)
# --------第10轮训练开始---------
# 整体训练集上的loss：47.020344734191895(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.4606364965438843(越大越好)
# 整体测试集上的loss：6.455196261405945(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.3764705955982208(越大越好)
# --------第11轮训练开始---------
# 使用GPU训练100次的时间为：18.324087858200073
# 训练次数：400,loss:1.241024374961853
# 整体训练集上的loss：46.86651086807251(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.4623115658760071(越大越好)
# 整体测试集上的loss：6.499731183052063(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.364705890417099(越大越好)
# --------第12轮训练开始---------
# 整体训练集上的loss：46.554675340652466(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.46901172399520874(越大越好)
# 整体测试集上的loss：6.478200197219849(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.364705890417099(越大越好)
# --------第13轮训练开始---------
# 整体训练集上的loss：46.362210750579834(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.47068676352500916(越大越好)
# 整体测试集上的loss：6.485429286956787(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.364705890417099(越大越好)
# --------第14轮训练开始---------
# 使用GPU训练100次的时间为：11.418475151062012
# 训练次数：500,loss:1.1758289337158203
# 整体训练集上的loss：46.09953224658966(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.4757118821144104(越大越好)
# 整体测试集上的loss：6.39082407951355(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.3764705955982208(越大越好)
# --------第15轮训练开始---------
# 整体训练集上的loss：45.843913555145264(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.4773869216442108(越大越好)
# 整体测试集上的loss：6.401383876800537(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.364705890417099(越大越好)
# --------第16轮训练开始---------
# 整体训练集上的loss：45.64862668514252(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.4773869216442108(越大越好)
# 整体测试集上的loss：6.417111396789551(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.364705890417099(越大越好)
# --------第17轮训练开始---------
# 使用GPU训练100次的时间为：4.516686916351318
# 训练次数：600,loss:1.2014106512069702
# 整体训练集上的loss：45.47679424285889(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.47403684258461(越大越好)
# 整体测试集上的loss：6.4155004024505615(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.3529411852359772(越大越好)
# --------第18轮训练开始---------
# 整体训练集上的loss：45.27423703670502(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.47068676352500916(越大越好)
# 整体测试集上的loss：6.292074084281921(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.3764705955982208(越大越好)
# --------第19轮训练开始---------
# 使用GPU训练100次的时间为：20.803452253341675
# 训练次数：700,loss:1.1510359048843384
# 整体训练集上的loss：45.023751616477966(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.4773869216442108(越大越好)
# 整体测试集上的loss：6.367621421813965(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.364705890417099(越大越好)
# --------第20轮训练开始---------
# 整体训练集上的loss：44.855894923210144(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.47906196117401123(越大越好)
# 整体测试集上的loss：6.32676100730896(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.364705890417099(越大越好)
# --------第21轮训练开始---------
# 整体训练集上的loss：44.62529003620148(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.4773869216442108(越大越好)
# 整体测试集上的loss：6.354223370552063(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.3529411852359772(越大越好)
# --------第22轮训练开始---------
# 使用GPU训练100次的时间为：13.936346292495728
# 训练次数：800,loss:1.3222832679748535
# 整体训练集上的loss：44.34296643733978(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.47906196117401123(越大越好)
# 整体测试集上的loss：6.16697084903717(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.3764705955982208(越大越好)
# --------第23轮训练开始---------
# 整体训练集上的loss：44.23831748962402(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.48408710956573486(越大越好)
# 整体测试集上的loss：6.219289064407349(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.3764705955982208(越大越好)
# --------第24轮训练开始---------
# 整体训练集上的loss：44.05399012565613(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.4891122281551361(越大越好)
# 整体测试集上的loss：6.2411017417907715(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.3764705955982208(越大越好)
# --------第25轮训练开始---------
# 使用GPU训练100次的时间为：7.031881093978882
# 训练次数：900,loss:1.2531458139419556
# 整体训练集上的loss：43.76371943950653(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.4874371886253357(越大越好)
# 整体测试集上的loss：6.158730626106262(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.3529411852359772(越大越好)
# --------第26轮训练开始---------
# 整体训练集上的loss：43.684990644454956(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.49581238627433777(越大越好)
# 整体测试集上的loss：6.187311053276062(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.364705890417099(越大越好)
# --------第27轮训练开始---------
# 整体训练集上的loss：43.44559192657471(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.5058626532554626(越大越好)
# 整体测试集上的loss：6.111324429512024(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.364705890417099(越大越好)
# --------第28轮训练开始---------
# 使用GPU训练100次的时间为：0.12647581100463867
# 训练次数：1000,loss:1.2159147262573242
# 整体训练集上的loss：43.256623923778534(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.5025125741958618(越大越好)
# 整体测试集上的loss：6.182677745819092(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.3529411852359772(越大越好)
# --------第29轮训练开始---------
# 整体训练集上的loss：43.00808501243591(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.5058626532554626(越大越好)
# 整体测试集上的loss：6.103185176849365(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.38823530077934265(越大越好)
# --------第30轮训练开始---------
# 使用GPU训练100次的时间为：16.43382740020752
# 训练次数：1100,loss:1.2853847742080688
# 整体训练集上的loss：42.74533140659332(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.5293132066726685(越大越好)
# 整体测试集上的loss：6.089298963546753(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.3764705955982208(越大越好)
# --------第31轮训练开始---------
# 整体训练集上的loss：42.5662624835968(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.5242881178855896(越大越好)
# 整体测试集上的loss：6.129910230636597(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.3529411852359772(越大越好)
# --------第32轮训练开始---------
# 整体训练集上的loss：42.32987201213837(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.5343383550643921(越大越好)
# 整体测试集上的loss：6.052361726760864(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.4000000059604645(越大越好)
# --------第33轮训练开始---------
# 使用GPU训练100次的时间为：9.542255401611328
# 训练次数：1200,loss:1.27019464969635
# 整体训练集上的loss：42.18624150753021(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.5544388294219971(越大越好)
# 整体测试集上的loss：6.04612135887146(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.4117647111415863(越大越好)
# 已修改模型
# --------第34轮训练开始---------
# 整体训练集上的loss：41.9517058134079(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.5561138987541199(越大越好)
# 整体测试集上的loss：6.1014484167099(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.38823530077934265(越大越好)
# --------第35轮训练开始---------
# 整体训练集上的loss：41.779744386672974(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.5745393633842468(越大越好)
# 整体测试集上的loss：6.017502307891846(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.38823530077934265(越大越好)
# --------第36轮训练开始---------
# 使用GPU训练100次的时间为：2.6249284744262695
# 训练次数：1300,loss:1.099668264389038
# 整体训练集上的loss：41.60916578769684(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.5745393633842468(越大越好)
# 整体测试集上的loss：5.952912926673889(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.42352941632270813(越大越好)
# 已修改模型
# --------第37轮训练开始---------
# 整体训练集上的loss：41.28447824716568(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.5845896005630493(越大越好)
# 整体测试集上的loss：5.963742017745972(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.4117647111415863(越大越好)
# --------第38轮训练开始---------
# 使用GPU训练100次的时间为：18.933192014694214
# 训练次数：1400,loss:1.1538896560668945
# 整体训练集上的loss：41.184056758880615(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.6046901345252991(越大越好)
# 整体测试集上的loss：5.954734563827515(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.47058823704719543(越大越好)
# 已修改模型
# --------第39轮训练开始---------
# 整体训练集上的loss：40.92912703752518(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.6415410041809082(越大越好)
# 整体测试集上的loss：5.915401101112366(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.48235294222831726(越大越好)
# 已修改模型
# --------第40轮训练开始---------
# 整体训练集上的loss：40.76177763938904(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.6381909251213074(越大越好)
# 整体测试集上的loss：5.9963297843933105(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.4588235318660736(越大越好)
# --------第41轮训练开始---------
# 使用GPU训练100次的时间为：12.050480127334595
# 训练次数：1500,loss:0.9996985793113708
# 整体训练集上的loss：40.500378012657166(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.6415410041809082(越大越好)
# 整体测试集上的loss：5.878055572509766(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.4588235318660736(越大越好)
# --------第42轮训练开始---------
# 整体训练集上的loss：40.350848376750946(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.6398659944534302(越大越好)
# 整体测试集上的loss：5.940040946006775(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.4588235318660736(越大越好)
# --------第43轮训练开始---------
# 整体训练集上的loss：40.14552539587021(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.6549413800239563(越大越好)
# 整体测试集上的loss：5.884169697761536(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.47058823704719543(越大越好)
# --------第44轮训练开始---------
# 使用GPU训练100次的时间为：5.1370689868927
# 训练次数：1600,loss:1.0909836292266846
# 整体训练集上的loss：39.855180978775024(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.6599664688110352(越大越好)
# 整体测试集上的loss：5.723472833633423(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.4941176474094391(越大越好)
# 已修改模型
# --------第45轮训练开始---------
# 整体训练集上的loss：39.626508712768555(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.6649916172027588(越大越好)
# 整体测试集上的loss：5.851069092750549(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.48235294222831726(越大越好)
# --------第46轮训练开始---------
# 使用GPU训练100次的时间为：21.45922350883484
# 训练次数：1700,loss:1.1242423057556152
# 整体训练集上的loss：39.42318940162659(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.6683416962623596(越大越好)
# 整体测试集上的loss：5.860346853733063(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.48235294222831726(越大越好)
# --------第47轮训练开始---------
# 整体训练集上的loss：39.33861517906189(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.6700167655944824(越大越好)
# 整体测试集上的loss：5.746517896652222(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.4941176474094391(越大越好)
# --------第48轮训练开始---------
# 整体训练集上的loss：39.01828467845917(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.6716917753219604(越大越好)
# 整体测试集上的loss：5.82772958278656(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.4941176474094391(越大越好)
# --------第49轮训练开始---------
# 使用GPU训练100次的时间为：14.553661823272705
# 训练次数：1800,loss:1.1697264909744263
# 整体训练集上的loss：38.703522086143494(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.6716917753219604(越大越好)
# 整体测试集上的loss：5.757627010345459(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.48235294222831726(越大越好)
# --------第50轮训练开始---------
# 整体训练集上的loss：38.511178493499756(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.6783919334411621(越大越好)
# 整体测试集上的loss：5.803435444831848(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.47058823704719543(越大越好)
# --------第51轮训练开始---------
# 整体训练集上的loss：38.38068777322769(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.6716917753219604(越大越好)
# 整体测试集上的loss：5.74104630947113(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.48235294222831726(越大越好)
# --------第52轮训练开始---------
# 使用GPU训练100次的时间为：7.647661209106445
# 训练次数：1900,loss:1.0501976013183594
# 整体训练集上的loss：38.215212404727936(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.6700167655944824(越大越好)
# 整体测试集上的loss：5.7066428661346436(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.48235294222831726(越大越好)
# --------第53轮训练开始---------
# 整体训练集上的loss：38.04359430074692(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.6800670027732849(越大越好)
# 整体测试集上的loss：5.58023464679718(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.4941176474094391(越大越好)
# --------第54轮训练开始---------
# 整体训练集上的loss：37.84399622678757(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.6750418543815613(越大越好)
# 整体测试集上的loss：5.601839959621429(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.4941176474094391(越大越好)
# --------第55轮训练开始---------
# 使用GPU训练100次的时间为：0.7454428672790527
# 训练次数：2000,loss:1.0247334241867065
# 整体训练集上的loss：37.586830377578735(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.6867671608924866(越大越好)
# 整体测试集上的loss：5.607314586639404(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.48235294222831726(越大越好)
# --------第56轮训练开始---------
# 整体训练集上的loss：37.3904824256897(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.6783919334411621(越大越好)
# 整体测试集上的loss：5.5506356954574585(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.5058823823928833(越大越好)
# 已修改模型
# --------第57轮训练开始---------
# 使用GPU训练100次的时间为：17.053713083267212
# 训练次数：2100,loss:1.0378243923187256
# 整体训练集上的loss：37.16881662607193(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.6850920915603638(越大越好)
# 整体测试集上的loss：5.565069675445557(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.5176470875740051(越大越好)
# 已修改模型
# --------第58轮训练开始---------
# 整体训练集上的loss：36.98272806406021(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.6901172399520874(越大越好)
# 整体测试集上的loss：5.555685043334961(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.4941176474094391(越大越好)
# --------第59轮训练开始---------
# 整体训练集上的loss：36.81919074058533(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.6917923092842102(越大越好)
# 整体测试集上的loss：5.62106329202652(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.4941176474094391(越大越好)
# --------第60轮训练开始---------
# 使用GPU训练100次的时间为：10.163420677185059
# 训练次数：2200,loss:1.0648986101150513
# 整体训练集上的loss：36.644493758678436(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.6917923092842102(越大越好)
# 整体测试集上的loss：5.551156282424927(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.4941176474094391(越大越好)
# --------第61轮训练开始---------
# 整体训练集上的loss：36.46496766805649(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.6850920915603638(越大越好)
# 整体测试集上的loss：5.597709655761719(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.47058823704719543(越大越好)
# --------第62轮训练开始---------
# 整体训练集上的loss：36.179329335689545(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.6934673190116882(越大越好)
# 整体测试集上的loss：5.467376947402954(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.4941176474094391(越大越好)
# --------第63轮训练开始---------
# 使用GPU训练100次的时间为：3.2730917930603027
# 训练次数：2300,loss:0.9967542290687561
# 整体训练集上的loss：35.86975693702698(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.6968173980712891(越大越好)
# 整体测试集上的loss：5.4559876918792725(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.48235294222831726(越大越好)
# --------第64轮训练开始---------
# 整体训练集上的loss：35.73875457048416(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.6934673190116882(越大越好)
# 整体测试集上的loss：5.544983446598053(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.47058823704719543(越大越好)
# --------第65轮训练开始---------
# 使用GPU训练100次的时间为：19.571815729141235
# 训练次数：2400,loss:1.0260486602783203
# 整体训练集上的loss：35.52296453714371(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.6917923092842102(越大越好)
# 整体测试集上的loss：5.4570088386535645(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.48235294222831726(越大越好)
# --------第66轮训练开始---------
# 整体训练集上的loss：35.28991687297821(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.6867671608924866(越大越好)
# 整体测试集上的loss：5.4331382513046265(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.48235294222831726(越大越好)
# --------第67轮训练开始---------
# 整体训练集上的loss：35.10873103141785(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.6968173980712891(越大越好)
# 整体测试集上的loss：5.421449184417725(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.4941176474094391(越大越好)
# --------第68轮训练开始---------
# 使用GPU训练100次的时间为：12.673758745193481
# 训练次数：2500,loss:0.9883940815925598
# 整体训练集上的loss：34.98406785726547(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.695142388343811(越大越好)
# 整体测试集上的loss：5.422530353069305(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.48235294222831726(越大越好)
# --------第69轮训练开始---------
# 整体训练集上的loss：34.65838146209717(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.6984924674034119(越大越好)
# 整体测试集上的loss：5.386499762535095(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.4941176474094391(越大越好)
# --------第70轮训练开始---------
# 整体训练集上的loss：34.560627460479736(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.7018425464630127(越大越好)
# 整体测试集上的loss：5.259823322296143(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.4941176474094391(越大越好)
# --------第71轮训练开始---------
# 使用GPU训练100次的时间为：5.771565675735474
# 训练次数：2600,loss:1.012960433959961
# 整体训练集上的loss：34.34019923210144(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.7001674771308899(越大越好)
# 整体测试集上的loss：5.263476133346558(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.5058823823928833(越大越好)
# --------第72轮训练开始---------
# 整体训练集上的loss：33.98410642147064(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.7018425464630127(越大越好)
# 整体测试集上的loss：5.2744468450546265(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.4941176474094391(越大越好)
# --------第73轮训练开始---------
# 使用GPU训练100次的时间为：22.092154026031494
# 训练次数：2700,loss:1.0727499723434448
# 整体训练集上的loss：33.754750192165375(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.7068676352500916(越大越好)
# 整体测试集上的loss：5.1247371435165405(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.5176470875740051(越大越好)
# --------第74轮训练开始---------
# 整体训练集上的loss：33.67508602142334(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.7018425464630127(越大越好)
# 整体测试集上的loss：5.293043076992035(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.48235294222831726(越大越好)
# --------第75轮训练开始---------
# 整体训练集上的loss：33.62022262811661(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.695142388343811(越大越好)
# 整体测试集上的loss：5.192538738250732(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.5058823823928833(越大越好)
# --------第76轮训练开始---------
# 使用GPU训练100次的时间为：15.183446168899536
# 训练次数：2800,loss:1.1360636949539185
# 整体训练集上的loss：33.30057907104492(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.7001674771308899(越大越好)
# 整体测试集上的loss：5.182452023029327(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.5058823823928833(越大越好)
# --------第77轮训练开始---------
# 整体训练集上的loss：33.22422277927399(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.6984924674034119(越大越好)
# 整体测试集上的loss：5.319284200668335(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.47058823704719543(越大越好)
# --------第78轮训练开始---------
# 整体训练集上的loss：32.86554563045502(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.7001674771308899(越大越好)
# 整体测试集上的loss：5.166387975215912(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.5058823823928833(越大越好)
# --------第79轮训练开始---------
# 使用GPU训练100次的时间为：8.260676383972168
# 训练次数：2900,loss:1.0635967254638672
# 整体训练集上的loss：32.68615758419037(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.7102177739143372(越大越好)
# 整体测试集上的loss：5.070367991924286(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.5176470875740051(越大越好)
# --------第80轮训练开始---------
# 整体训练集上的loss：32.67171287536621(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.7035175561904907(越大越好)
# 整体测试集上的loss：5.159013152122498(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.5058823823928833(越大越好)
# --------第81轮训练开始---------
# 整体训练集上的loss：32.340084195137024(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.7085427045822144(越大越好)
# 整体测试集上的loss：4.99121767282486(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.529411792755127(越大越好)
# 已修改模型
# --------第82轮训练开始---------
# 使用GPU训练100次的时间为：1.3783552646636963
# 训练次数：3000,loss:0.944625973701477
# 整体训练集上的loss：32.09037917852402(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.7018425464630127(越大越好)
# 整体测试集上的loss：5.0134382247924805(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.4941176474094391(越大越好)
# --------第83轮训练开始---------
# 整体训练集上的loss：31.99717402458191(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.7051926255226135(越大越好)
# 整体测试集上的loss：5.140428423881531(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.5058823823928833(越大越好)
# --------第84轮训练开始---------
# 使用GPU训练100次的时间为：17.680963039398193
# 训练次数：3100,loss:0.8285868167877197
# 整体训练集上的loss：31.716059148311615(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.7102177739143372(越大越好)
# 整体测试集上的loss：5.204994440078735(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.5058823823928833(越大越好)
# --------第85轮训练开始---------
# 整体训练集上的loss：31.731988310813904(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.7068676352500916(越大越好)
# 整体测试集上的loss：5.137359857559204(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.5176470875740051(越大越好)
# --------第86轮训练开始---------
# 整体训练集上的loss：31.54220861196518(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.7118927836418152(越大越好)
# 整体测试集上的loss：5.084713459014893(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.5058823823928833(越大越好)
# --------第87轮训练开始---------
# 使用GPU训练100次的时间为：10.790281057357788
# 训练次数：3200,loss:0.8551382422447205
# 整体训练集上的loss：31.208234310150146(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.7085427045822144(越大越好)
# 整体测试集上的loss：5.081935286521912(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.48235294222831726(越大越好)
# --------第88轮训练开始---------
# 整体训练集上的loss：30.95741766691208(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.715242862701416(越大越好)
# 整体测试集上的loss：5.08891761302948(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.5058823823928833(越大越好)
# --------第89轮训练开始---------
# 整体训练集上的loss：30.822044789791107(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.7118927836418152(越大越好)
# 整体测试集上的loss：4.932601869106293(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.529411792755127(越大越好)
# --------第90轮训练开始---------
# 使用GPU训练100次的时间为：3.8862671852111816
# 训练次数：3300,loss:1.1503145694732666
# 整体训练集上的loss：30.705157577991486(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.7169179320335388(越大越好)
# 整体测试集上的loss：4.998090445995331(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.5176470875740051(越大越好)
# --------第91轮训练开始---------
# 整体训练集上的loss：30.47085005044937(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.7118927836418152(越大越好)
# 整体测试集上的loss：4.941960513591766(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.5058823823928833(越大越好)
# --------第92轮训练开始---------
# 使用GPU训练100次的时间为：20.214175939559937
# 训练次数：3400,loss:0.8451855778694153
# 整体训练集上的loss：30.483666837215424(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.7202680110931396(越大越好)
# 整体测试集上的loss：4.962465822696686(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.5176470875740051(越大越好)
# --------第93轮训练开始---------
# 整体训练集上的loss：30.333572149276733(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.7169179320335388(越大越好)
# 整体测试集上的loss：4.86727100610733(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.5176470875740051(越大越好)
# --------第94轮训练开始---------
# 整体训练集上的loss：29.92193102836609(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.7169179320335388(越大越好)
# 整体测试集上的loss：4.919617772102356(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.5058823823928833(越大越好)
# --------第95轮训练开始---------
# 使用GPU训练100次的时间为：13.295783996582031
# 训练次数：3500,loss:0.7455405592918396
# 整体训练集上的loss：29.75908237695694(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.7169179320335388(越大越好)
# 整体测试集上的loss：4.851616263389587(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.529411792755127(越大越好)
# --------第96轮训练开始---------
# 整体训练集上的loss：29.639907360076904(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.7202680110931396(越大越好)
# 整体测试集上的loss：5.007290482521057(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.48235294222831726(越大越好)
# --------第97轮训练开始---------
# 整体训练集上的loss：29.435187816619873(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.7202680110931396(越大越好)
# 整体测试集上的loss：4.905894458293915(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.5058823823928833(越大越好)
# --------第98轮训练开始---------
# 使用GPU训练100次的时间为：6.392679452896118
# 训练次数：3600,loss:0.8909128308296204
# 整体训练集上的loss：29.221601903438568(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.7236180901527405(越大越好)
# 整体测试集上的loss：4.797494530677795(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.529411792755127(越大越好)
# --------第99轮训练开始---------
# 整体训练集上的loss：29.00543838739395(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.7202680110931396(越大越好)
# 整体测试集上的loss：4.6618282198905945(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.529411792755127(越大越好)
# --------第100轮训练开始---------
# 使用GPU训练100次的时间为：22.719521522521973
# 训练次数：3700,loss:0.843089759349823
# 整体训练集上的loss：28.89534103870392(越小越好,与上面的loss无关此为测试集的总loss)
# 整体训练集上的正确率：0.7252930998802185(越大越好)
# 整体测试集上的loss：4.740290462970734(越小越好,与上面的loss无关此为测试集的总loss)
# 整体测试集上的正确率：0.5411764979362488(越大越好)
# 已修改模型
# 训练总共用时:1h:0m:2s

# %%
pip install tensorboard
# Out:
# Collecting tensorboard
#   Downloading tensorboard-2.19.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting absl-py>=0.4 (from tensorboard)
#   Downloading absl_py-2.3.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting grpcio>=1.48.2 (from tensorboard)
#   Downloading grpcio-1.73.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting markdown>=2.6.8 (from tensorboard)
#   Downloading markdown-3.8-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: numpy>=1.12.0 in /venv/main/lib/python3.12/site-packages (from tensorboard) (2.1.2)
# Requirement already satisfied: packaging in /venv/main/lib/python3.12/site-packages (from tensorboard) (25.0)
# Collecting protobuf!=4.24.0,>=3.19.6 (from tensorboard)
#   Downloading protobuf-6.31.1-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Requirement already satisfied: setuptools>=41.0.0 in /venv/main/lib/python3.12/site-packages (from tensorboard) (70.2.0)
# Requirement already satisfied: six>1.9 in /venv/main/lib/python3.12/site-packages (from tensorboard) (1.17.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard)
#   Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /venv/main/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard) (2.1.5)
# Downloading tensorboard-2.19.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 48.2 MB/s eta 0:00:0000:0100:01
# Downloading absl_py-2.3.0-py3-none-any.whl (135 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.7/135.7 kB 43.9 MB/s eta 0:00:00
# Downloading grpcio-1.73.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 105.5 MB/s eta 0:00:00a 0:00:01
# Downloading markdown-3.8-py3-none-any.whl (106 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.2/106.2 kB 37.2 MB/s eta 0:00:00
# Downloading protobuf-6.31.1-cp39-abi3-manylinux2014_x86_64.whl (321 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 321.1/321.1 kB 76.5 MB/s eta 0:00:00
# Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 87.2 MB/s eta 0:00:00:00:0100:01
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 60.7 MB/s eta 0:00:00
# Installing collected packages: werkzeug, tensorboard-data-server, protobuf, markdown, grpcio, absl-py, tensorboard
# Successfully installed absl-py-2.3.0 grpcio-1.73.0 markdown-3.8 protobuf-6.31.1 tensorboard-2.19.0 tensorboard-data-server-0.7.2 werkzeug-3.1.3
# Note: you may need to restart the kernel to use updated packages.
